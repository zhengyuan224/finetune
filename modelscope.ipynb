# %%
from modelscope import snapshot_download, AutoModel, AutoTokenizer

# %%
model_dir = snapshot_download('qwen/Qwen2-7B-Instruct',cache_dir='.')
# Out:
# Downloading: 100%|██████████| 663/663 [00:00<00:00, 1.73kB/s]
# Downloading: 100%|██████████| 48.0/48.0 [00:00<00:00, 131B/s]
# Downloading: 100%|██████████| 243/243 [00:00<00:00, 861B/s]
# Downloading: 100%|██████████| 11.1k/11.1k [00:00<00:00, 44.7kB/s]
# Downloading: 100%|██████████| 1.59M/1.59M [00:00<00:00, 4.27MB/s]
# Downloading: 100%|██████████| 3.67G/3.67G [02:04<00:00, 31.7MB/s]
# Downloading:  96%|█████████▋| 3.47G/3.60G [01:17<00:04, 33.7MB/s]2024-07-30 16:37:45,404 - modelscope - WARNING - Downloading: ./._____temp/qwen/Qwen2-7B-Instruct/model-00002-of-00004.safetensors failed, reason: HTTPSConnectionPool(host='www.modelscope.cn', port=443): Read timed out. will retry
# Downloading: 3.63GB [01:44, 37.2MB/s]
# Downloading: 100%|██████████| 3.60G/3.60G [01:51<00:00, 34.7MB/s]
# Downloading: 100%|██████████| 3.31G/3.31G [01:10<00:00, 50.3MB/s]
# Downloading: 100%|██████████| 27.1k/27.1k [00:00<00:00, 101kB/s]
# Downloading: 100%|██████████| 6.41k/6.41k [00:00<00:00, 15.8kB/s]
# Downloading: 100%|██████████| 6.70M/6.70M [00:02<00:00, 2.88MB/s]
# Downloading: 100%|██████████| 1.26k/1.26k [00:00<00:00, 4.77kB/s]
# Downloading: 100%|██████████| 2.65M/2.65M [00:00<00:00, 5.43MB/s]

# %%
qwen/Qwen2-7B-Instruct
# Out:
#   Cell In[1], line 1
#     qwen/Qwen2-7B-Instruct
#                ^
# SyntaxError: invalid decimal literal
